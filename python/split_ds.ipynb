# %%
import pandas as pd

# %%
dataset_path =r'E:\work\masters\Trento\Academics\Semesters\Year 1 Semester 1\146069 Next Generation Networks\project\execution\data\Data\RTT_data_split.csv' 
dataset_path_split =r'E:\work\masters\Trento\Academics\Semesters\Year 1 Semester 1\146069 Next Generation Networks\project\execution\data\Data\RTT_data_split2.csv'

# %%
RTT_data = pd.read_csv(dataset_path)
RTT_data
# Out:
#        Unnamed: 0  %Timestamp[s]  GroundTruthPositionX[m]  \
# 0               0         1894.6                  -42.039
# 1               1         1894.7                  -42.039
# 2               2         1894.7                  -42.039
# 3               3         1895.2                  -42.039
# 4               4         1895.3                  -42.039
# ...           ...            ...                      ...
# 14785       14785         1198.8                  -30.908
# 14786       14786         1198.8                  -30.908
# 14787       14787         1199.4                  -30.912
# 14788       14788         1199.4                  -30.912
# 14789       14789         1199.4                  -30.912
#
#        GroundTruthPositionY[m]  GroundTruthPositionZ[m]  ML_range_estimate[m]  \
# 0                       21.463                     45.5               36.2620
# 1                       21.463                     45.5               28.1600
# ...

# %%
split_point =int(RTT_data.shape[0]/2)

df_1 = RTT_data.iloc[:split_point,:]

#df_2 = RTT_data.iloc[1001:,:]
df_1.shape
df_1.to_csv(dataset_path_split)
